# %% [markdown]
# ### Read and show an image

# %% [markdown]
# 1. Using matplotlib

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# read a grayscale image and plot it
img = mpimg.imread("apple.jpeg")
plt.imshow(img, cmap="gray")
plt.show()
# Out:
# (1204, 1880)
